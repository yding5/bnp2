# %%
using DrWatson
@quickactivate "BNP2"
using BNP2

;

# %%
preview_frames(datadir("pymunk-bouncing_ball", "video-11"), 11:15)

;
# Out:
# PyPlot.Figure(PyObject <Figure size 1500x300 with 5 Axes>)
# size(img): (128, 128, 3)
