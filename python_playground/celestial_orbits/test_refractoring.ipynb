# %%
import sys
sys.path.append('.')
import universe
import body
from IPython.display import HTML

# %%
#Test data
bodies=[]
bodies.append(body.Body(1.1, -.5, 0, 0, 0.01, 0, 0.01))
bodies.append(body.Body(0.907, .5, 0, 0, -0.05, -0.1, 0))
bodies.append(body.Body(1., 0, 0, 1, 0.09, 0, -0.01))

uni = universe.Universe()
anim,_ = uni.run_simulation(bodies)

#Test Vis
HTML(anim.to_html5_video())
# Out:
# Net Constants:
# K1:  0.20048437269236738
# K2:  7.239323869320315
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
